# %%
import seaborn as sns


anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import matplotlib.pyplot as plt


dataset_1 = anscombe[anscombe['dataset'] == 'I']
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
count, ax = plt.subplots()
ax = sns.countplot(tips, x='day')
ax.set_title("Count of days")
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.lmplot(tips, x='total_bill', y='tip', fit_reg=False)

# %%
sns.lmplot(tips, x='total_bill', y='tip')

# %%
sns.lmplot(tips, x='total_bill', y='tip', hue='sex', fit_reg=False)

# %%
joint = sns.jointplot(tips, x='total_bill', y='tip')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle("Joint Plot of Total Bill and Trip", fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Trip')

# %%
hexbin = sns.jointplot(tips, x='total_bill', y='tip', kind='hex')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle("Hexbin Joint Plot of Total Bill and Trip", fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Trip')

# %%
kde, ax = plt.subplots()
ax = sns.kdeplot(tips, x='total_bill', y='tip', fill=True)
ax.set_title("Kernel Density Plot of Total Bill and Tip")
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
kde_joint = sns.jointplot(tips, x='total_bill', y='tip', kind='kde')

# %%
bar, ax = plt.subplots()
ax = sns.barplot(tips, x='time', y='total_bill')
ax.set_title("Bar Plot of average total bill for time of day")
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
box, ax = plt.subplots()
ax = sns.boxplot(tips, x='time', y='total_bill')
ax.set_title("Boxplot of total bill by time of day")
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# Text(0, 0.5, 'Total bill')

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.histplot)

# %%
violin, ax = plt.subplots()
ax = sns.violinplot(tips, x='time', y='total_bill', hue='sex', split=True)

# %%
fig = sns.pairplot(tips, hue='sex')

# %%
scatter = sns.lmplot(tips, x='total_bill', y='tip', hue='sex', fit_reg=False, markers=['o', 'x'])

# %%
anscombe_plot = sns.lmplot(anscombe, x='x', y='y', fit_reg=False, col='dataset', col_wrap=2)

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.histplot, 'total_bill')

# %%
fig = sns.lmplot(tips, x='total_bill', y='tip', fit_reg=False, hue='sex', col='day')

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %%
facet = sns.catplot(tips, x='day', y='total_bill', hue='sex', row='smoker', col='time', kind='violin')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips,
           hue='sex', col='day', row='smoker', fit_reg=False)

# %%
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(tips, x='time', y='total_bill', hue='sex', split=True)

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(tips, x='time', y='total_bill', hue='sex', split=True)

# %%
fig = plt.figure()
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(tips, x='time', y='total_bill', ax=ax)
        violin.set_title(style)
fig.tight_layout()
